# %%
import pandas as pd
root = "/data/kyungbok/FakeAVCeleb_v1.2"

# %%
df = pd.read_csv(root + "/meta_data.csv")
df.head()
print(len(df))
# Out:
# 21566

# %%
df_E = df[df["category"] == "B"]
df_E
# Out:
#       source   target1 target2 method category                 type  \
# 500  id00076  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 501  id00166  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 502  id00173  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 503  id00366  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 504  id00391  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# ..       ...       ...     ...    ...      ...                  ...
# 995  id07136  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 996  id07236  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 997  id07377  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 998  id07686  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 999  id07689  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
#
#               race gender            path  \
# 500        African    men  00109_fake.mp4
# 501        African    men  00010_fake.mp4
# ...

# %%
# change the category of the data
df_E.loc[:, "category"] = "E"
df_E.loc[:, "method"] = "freevc"
df_E
# Out:
# /tmp/ipykernel_2347885/455873146.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_E.loc[:, "category"] = "E"
# /tmp/ipykernel_2347885/455873146.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_E.loc[:, "method"] = "freevc"
#       source   target1 target2  method category                 type  \
# 500  id00076  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 501  id00166  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# ...

# %%
final_df = pd.concat([df, df_E])
final_df[final_df["category"] == "E"]
# Out:
#       source   target1 target2  method category                 type  \
# 500  id00076  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 501  id00166  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 502  id00173  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 503  id00366  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 504  id00391  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# ..       ...       ...     ...     ...      ...                  ...
# 995  id07136  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 996  id07236  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 997  id07377  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 998  id07686  fake.mp4       -  freevc        E  RealVideo-FakeAudio
# 999  id07689  fake.mp4       -  freevc        E  RealVideo-FakeAudio
#
#               race gender            path  \
# 500        African    men  00109_fake.mp4
# 501        African    men  00010_fake.mp4
# ...

# %%
final_df[final_df["category"] == "B"]
# Out:
#       source   target1 target2 method category                 type  \
# 500  id00076  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 501  id00166  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 502  id00173  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 503  id00366  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 504  id00391  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# ..       ...       ...     ...    ...      ...                  ...
# 995  id07136  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 996  id07236  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 997  id07377  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 998  id07686  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
# 999  id07689  fake.mp4       -   rtvc        B  RealVideo-FakeAudio
#
#               race gender            path  \
# 500        African    men  00109_fake.mp4
# 501        African    men  00010_fake.mp4
# ...

# %%
print(len(final_df))
# Out:
# 22066

# %%
final_df.to_csv(root + "/meta_data_added.csv", index=False)

# %%
df = pd.read_csv(root + "/meta_data_added.csv")
df.head()
# Out:
#     source target1 target2 method category                 type     race  \
# 0  id00076       -       -   real        A  RealVideo-RealAudio  African
# 1  id00166       -       -   real        A  RealVideo-RealAudio  African
# 2  id00173       -       -   real        A  RealVideo-RealAudio  African
# 3  id00366       -       -   real        A  RealVideo-RealAudio  African
# 4  id00391       -       -   real        A  RealVideo-RealAudio  African
#
#   gender       path                                         Unnamed: 9
# 0    men  00109.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 1    men  00010.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 2    men  00118.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 3    men  00118.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 4    men  00052.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...

# %%
df_F = df[df["category"] == "A"]
df_F.head()
# Out:
#     source target1 target2 method category                 type     race  \
# 0  id00076       -       -   real        A  RealVideo-RealAudio  African
# 1  id00166       -       -   real        A  RealVideo-RealAudio  African
# 2  id00173       -       -   real        A  RealVideo-RealAudio  African
# 3  id00366       -       -   real        A  RealVideo-RealAudio  African
# 4  id00391       -       -   real        A  RealVideo-RealAudio  African
#
#   gender       path                                         Unnamed: 9
# 0    men  00109.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 1    men  00010.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 2    men  00118.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 3    men  00118.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 4    men  00052.mp4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...

# %%
df_F.loc[:, "category"] = "F"
df_F.loc[:, "method"] = "shifted"
df_F.head()
# Out:
# /tmp/ipykernel_2438202/2460568250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_F.loc[:, "category"] = "F"
# /tmp/ipykernel_2438202/2460568250.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_F.loc[:, "method"] = "shifted"
#     source target1 target2   method category                 type     race  \
# 0  id00076       -       -  shifted        F  RealVideo-RealAudio  African
# 1  id00166       -       -  shifted        F  RealVideo-RealAudio  African
# ...

# %%
final_df = pd.concat([df, df_F])
print(len(final_df))
# Out:
# 22566

# %%
final_df.to_csv(root + "/meta_data_added.csv", index=False)

# %%
df = pd.read_csv(root + "/meta_data_added.csv")
df[df["category"] == "F"]
# Out:
#         source target1 target2   method category                 type  \
# 22066  id00076       -       -  shifted        F  RealVideo-RealAudio
# 22067  id00166       -       -  shifted        F  RealVideo-RealAudio
# 22068  id00173       -       -  shifted        F  RealVideo-RealAudio
# 22069  id00366       -       -  shifted        F  RealVideo-RealAudio
# 22070  id00391       -       -  shifted        F  RealVideo-RealAudio
# ...        ...     ...     ...      ...      ...                  ...
# 22561  id07136       -       -  shifted        F  RealVideo-RealAudio
# 22562  id07236       -       -  shifted        F  RealVideo-RealAudio
# 22563  id07377       -       -  shifted        F  RealVideo-RealAudio
# 22564  id07686       -       -  shifted        F  RealVideo-RealAudio
# 22565  id07689       -       -  shifted        F  RealVideo-RealAudio
#
#                 race gender       path  \
# 22066        African    men  00109.mp4
# 22067        African    men  00010.mp4
# ...
